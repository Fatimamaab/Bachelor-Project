# %%
# !pip install yt-dlp

# %%
# !yt-dlp -f mp4 "https://www.youtube.com/watch?v=IODxDxX7oi4" -o "pushup_sample.mp4"
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IODxDxX7oi4
# [youtube] IODxDxX7oi4: Downloading webpage
# [youtube] IODxDxX7oi4: Downloading tv client config
# [youtube] IODxDxX7oi4: Downloading player 12b61286-main
# [youtube] IODxDxX7oi4: Downloading tv player API JSON
# [youtube] IODxDxX7oi4: Downloading ios player API JSON
# [youtube] IODxDxX7oi4: Downloading m3u8 information
# [info] IODxDxX7oi4: Downloading 1 format(s): 18
# [download] pushup_sample.mp4 has already been downloaded
#
# [download] 100% of    6.62MiB

# %%
# !pip install mediapipe

# %%
from pushup_feedback import PushUpFeedback

analyzer = PushUpFeedback("Final_pushup_cnn_Bilstm_model.keras")

analyzer.analyze_from_video("pushup_sample.mp4", frame_index=50)
# Out:
# Video opened: True
# Frame count: 6510
# Pose sequence shape: (150, 66)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
#
# Predicted Class: Correct (0.86 confidence)
#
# --- Sample Feedback (first 10 frames) ---
# Frame 1: Left elbow too extended (173.3 degree), aim for ~110 degree
# Frame 2: Left elbow too extended (175.5 degree), aim for ~110 degree, Right elbow too extended (171.6 degree), aim for ~110 degree
# Frame 3: Right elbow too extended (173.9 degree), aim for ~110 degree
# Frame 4: Right elbow too extended (175.8 degree), aim for ~110 degree, Uneven Form
# Frame 5: Right elbow too extended (173.3 degree), aim for ~110 degree, Uneven Form
# Frame 6: Right elbow too extended (173.4 degree), aim for ~110 degree, Uneven Form
# Frame 7: Right elbow too extended (171.0 degree), aim for ~110 degree, Uneven Form
# Frame 8: Right elbow too extended (171.4 degree), aim for ~110 degree, Uneven Form
# Frame 9: Right elbow too extended (171.7 degree), aim for ~110 degree, Uneven Form
# ...
